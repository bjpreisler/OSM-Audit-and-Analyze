# %% [markdown]
# ## Denver Open Street Map Munging
# ### Map Area
#
# Denver, CO, United States
# * http://www.openstreetmap.org/relation/253750
#
# I currently live and work in Denver but am new to the area so I thought I'd explore the OSM
# data and see what it contains
#
# ### Problems contained in data set
# I first downloaded a much smaller sample set to start invesigating any problems. Below is what
# I found and how I addressed the issues:

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import pprint
import re

OSMFILE = "denver-boulder_colorado.osm"

# %%
def count_tags(filename):
    dct = {}
    lst = []
    for event, element in ET.iterparse(filename):
        unique_tag = element.tag
        lst.append(unique_tag)
    for i in lst:
        if i in dct.keys():
            dct[i] += 1
        else:
            dct[i] = 1
    return dct

count_tags(OSMFILE)
# Out:
# {'bounds': 1,
#  'member': 38084,
#  'nd': 4455819,
#  'node': 3845096,
#  'osm': 1,
#  'relation': 2106,
#  'tag': 2107079,
#  'way': 430132}

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_types = defaultdict(set)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Circle", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Way"]

# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "Ave":"Avenue",
           "Ave.":"Avenue",
            "Rd.":"Road",
           "Rd":"Road",
           "Dr":"Drive",
           "Pky":"Parkway",
           "Pkwy":"Parkway",
           "ct":"Court",
           "Ct":"Court",
           "Cir":"Circle",
           "Pl":"Place"
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
    if street_type in mapping.keys():
        name = re.sub(street_type, mapping[street_type], name)
    return name

# %%
def test():
    st_types = audit(OSMFILE)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name

# %%
test()
# Out:
# {'100': set(['15th Street Suite 100',
#              'Sheridan Boulevard #100',
#              'South Ridgeline Blvd, Suite 100']),
#  '103': set(['15th Street #103']),
#  '104': set(['Cherry Creek S Dr #104']),
#  '106': set(['Landmark Way, Suite 106']),
#  '107': set(['Dorchester St #107']),
#  '110': set(['E. Mineral Avenue, Suite 110', 'W Cross Dr #110']),
#  '115': set(['East Iliff Avenue #115']),
#  '119': set(['Highway 119', 'State Highway 119']),
#  '120': set(['West 120th Avenue, Ste 120']),
#  '126': set(['County Rd 126']),
#  '130': set(['E Caley Ave #130']),
#  '140': set(['East Arapahoe Road, #140']),
#  '154': set(['West 136th Avenue Unit 154']),
#  '1606': set(['1606']),
#  '169': set(['S Broadway #169']),
#  '186': set(['County Road 186']),
#  '19': set(['South Rock Creek Parkway, Building 19']),
#  '2': set(['Colorado SH 2',
#            'Colorado SR 2',
#            'Delaware St Unit 2',
#            'SR 2',
#            'State Highway 2']),
#  '200': set(['S Bellaire St #200', 'Wadsworth Boulevard, Ste. 200']),
#  '200c': set(['West 25th Avenue Suit 200c']),
#  '220': set(['South Colorado Boulevard, #220']),
#  '220H': set(['30th St #220H']),
#  '285': set(['Highway 285', 'US Highway 285', 'US Hwy 285']),
#  '287': set(['Highway 287', 'South Highway 287', 'US Highway 287']),
#  '300': set(['Commerce Center Cir #300',
#              'Crown Crest Blvd., Suite 300',
#              'Delaware St #300',
#              'Wadsworth Boulevard, Ste 300']),
#  '303': set(['Folsom Street, #303']),
#  '314': set(['County Road 314']),
#  '320': set(['E Arapahoe Rd Tower 1 #320']),
#  '40': set(['US Highway 40', 'US Hwy 40']),
#  '400': set(['Wadsworth Boulevard Ste 400']),
#  '41': set(['County Road 41']),
#  '45': set(['County Road 45']),
#  '500': set(['Weaver Park Rd #500']),
#  '52': set(['I-76 & CO Hwy 52', 'State Highway 52']),
#  '59': set(['Weld County Road 59']),
#  '5B': set(['Sheridan Boulevard 5B', 'Sheridan Boulevard Unit 5B']),
#  '6001': set(['6001']),
#  '6300': set(['East 19th Avenue  #6300']),
#  '65': set(['County Road 65']),
#  '6523': set(['6523']),
#  '68th': set(['68th']),
#  '7': set(['County Road 7',
#            'SH 7',
#            'State Highway 7',
#            'West State Highway 7']),
#  '700': set(['Broadway, Ste 700']),
#  '72': set(['CO 72', 'County Road 72', 'Park 72']),
#  '73': set(['CO Highway 73', 'County Road 73', 'Hwy 73']),
#  '7331': set(['P.O. Box 7331']),
#  '74': set(['Colorado 74', 'County Road 74', 'Highway 74', 'Hwy 74']),
#  '8': set(['49th St #8', 'CO HWY 8']),
#  '80208': set(['2148 S. High Street, Denver, Colorado, 80208']),
#  '80305': set(['1190 South Lashley Lane Boulder, CO 80305']),
#  '83': set(['Colorado Highway 83',
#             'North State Highway 83',
#             'State Highway 83']),
#  '85': set(['US 85']),
#  '850': set(['Santa Fe Drive, Unit #850']),
#  '86': set(['State Highway 86']),
#  '8765': set(['8765']),
#  '88th': set(['E 88th']),
#  '93': set(['Hwy 72 & Hwy 93']),
#  '9k': set(['S Alton Way #9k']),
#  'A': set(['South Road A']),
#  'Ace': set(['4775 West 121st Ace', '5005 West 120th Ace']),
#  'Appia': set(['Via Appia']),
#  'Arapahoe': set(['Arapahoe']),
#  'Av': set(['W 56th Av', 'W Belleview Av']),
#  'Ave': set(['Arapahoe Ave',
#              'Cottonwood Ave',
#              'Dawn Ave',
#              'Dorado Ave',
#              'E 120th Ave',
#              'E 1st Ave',
#              'E 6th Ave',
#              'E 72nd Ave',
#              'E 84th Ave',
#              'E Arizona Ave',
#              'E Caley Ave',
#              'E Evans Ave',
#              'E Fair Ave',
#              'E Louisiana Ave',
#              'E Maplewood Ave',
#              'East Hampden Ave',
#              'East Mississippi Ave',
#              'Evans Ave',
#              'W 10th Ave',
#              'W 120th Ave',
#              'W 38th Ave',
#              'W 44th Ave',
#              'W 64th Ave',
#              'W 72nd Ave',
#              'W 84th Ave',
#              'W Floyd Ave',
#              'W Hampden Ave',
#              'W Ken Caryl Ave',
#              'W Plymouth Ave',
#              'W Quincy Ave',
#              'W. 10th Ave',
#              'W. 25th Ave',
#              'Washington Ave',
#              'West 120th Ave',
#              'West 136th Ave',
#              'Yarmouth Ave',
#              'w 67th Ave',
#              'w. 10th Ave']),
#  'Ave.': set(['11200 W. 64th Ave.',
#               'E. College Ave.',
#               'E. Mountain View Ave.',
#               'W. Alameda Ave.']),
#  'Avenue)': set(['East Bromley Lane (152nd Avenue)']),
#  'B': set(['4th Street Suite B', 'Colorado Blvd #B']),
#  'Baselin': set(['Baselin']),
#  'Baseline': set(['Baseline']),
#  'Bikeway': set(['US 36 Bikeway']),
#  'Blvd': set(['745 Colorado Blvd',
#               'Airport Blvd',
#               'Brighton Blvd',
#               'Colorado Blvd',
#               'East Academy Blvd',
#               'Eldorado Blvd',
#               'Federal Blvd',
#               'Green Valley Ranch Blvd',
#               'Ken Pratt Blvd',
#               'Martin Luther King Blvd',
#               'Martin Luther King Jr Blvd',
#               'McCaslin Blvd',
#               'N Federal Blvd',
#               'N Sheridan Blvd',
#               'S Lowell Blvd',
#               'S University  Blvd',
#               'S University Blvd',
#               'Sheridan Blvd',
#               'South Colorado Blvd',
#               'South University Blvd',
#               'Wadsworth Blvd',
#               'Wadworth Blvd']),
#  'Blvd.': set(['Sheridan Blvd.']),
#  'Boulder': set(['Boulder']),
#  'Broadway': set(['Broadway',
#                   'N Broadway',
#                   'North Broadway',
#                   'S Broadway',
#                   'S. Broadway',
#                   'South Broadway']),
#  'Bypass': set(['Wadsworth Bypass']),
#  'CO-119': set(['CO-119']),
#  'CO80229': set(['3101 E 100th Thornton, CO80229']),
#  'Camground': set(['West Magnolia Camground']),
#  'Campground': set(['West Magnolia Campground']),
#  'Caria': set(['Caria']),
#  'Centennial': set(['Centennial']),
#  'Center': set(['Garden Center']),
#  'Cherryvale': set(['Cherryvale']),
#  'Cir': set(['E Flatiron Cir',
#              'Highlands Cir',
#              'Rock Creek Cir',
#              'S Lake Cir']),
#  'Co-119': set(['Co-119']),
#  'Colfax': set(['East Colfax']),
#  'Colorado': set(['12354 West Alameda Parkway Lakewood Colorado']),
#  'Crescent': set(['Front View Crescent', 'Interlocken Crescent']),
#  'Ct': set(['North 57th Ct',
#             'Pear Lake Ct',
#             'Rodeo Ct',
#             'S Niagra Ct',
#             'South 57th Ct']),
#  'D': set(['E 3rd Ave #D', 'West Colfax Avenue, Unit D']),
#  'Dr': set(['Apache Dr',
#             'Broadlands Dr',
#             'Cabela Dr',
#             'Community Center Dr',
#             'Community Circle Dr',
#             'Conifer Town Denter Dr',
#             'Cowley Dr',
#             'Delwood Dr',
#             'Eisenhower Dr',
#             'Indian Peaks Dr',
#             'Lakeview Dr',
#             'Leetsdale Dr',
#             'Longs Peak Dr',
#             'Melody Dr',
#             'Reliance Dr',
#             'S Santa Fe Dr',
#             'Zotos Dr']),
#  'E': set(['1100 Ken Pratt Blvd Unit E', 'Main Street #E']),
#  'E1': set(['University Blvd, Suite E1']),
#  'East': set(['Inverness Court East',
#               'Inverness Drive East',
#               'South Chapparal Circle East',
#               'Sterling Circle East',
#               'Village Center Drive East']),
#  'Elm': set(['East Elm']),
#  'Etna': set(['Etna']),
#  'Grant': set(['Grant']),
#  'Highway': set(['Diagonal Highway',
#                  'North Valley Highway',
#                  'South Valley Highway',
#                  'Ute Highway']),
#  'Hwy': set(['S Valley Hwy']),
#  'K': set(['Norwood Drive Unit K']),
#  'Lamar': set(['Lamar']),
#  'Lincoln': set(['Lincoln']),
#  'Ln': set(['Lee Ln', 'Tuscany Ln']),
#  'Locust': set(['Yellow Locust']),
#  'Loop': set(['Eagle River Loop', 'Quay Loop']),
#  'MUP': set(['128th Ave MUP']),
#  'Main': set(['Main']),
#  'Mainstreet': set(['East Mainstreet']),
#  'Mall': set(['10th Street Mall',
#               'Central Campus Mall',
#               'Lawrence Street Mall',
#               'Pearl Street Mall']),
#  'Mine': set(['Coal Mine']),
#  'Newland': set(['Newland']),
#  'North': set(['57th Court North',
#                'Central Court North',
#                'East Speer Boulevard North',
#                'Nautilus Court North',
#                'Parkside Drive North']),
#  'Osage': set(['Osage']),
#  'Pennsylvania': set(['Pennsylvania']),
#  'Pkwy': set(['Castle Pines Pkwy',
#               'E Alameda Pkwy',
#               'Evergreen Pkwy',
#               'Orchard Pkwy',
#               'S Aurora Pkwy',
#               'S Kipling Pkwy',
#               'S Monaco Pkwy',
#               'S Platte River Pkwy',
#               'W Alameda Pkwy',
#               'Wadsworth Pkwy']),
#  'Pky': set(['DTC Pky']),
#  'Pl': set(['E Lake Pl',
#             'E Maplewood Pl',
#             'E Orchard Pl',
#             'Pinon Pl',
#             'W 16th Pl',
#             'W 88th Pl',
#             'W Lehigh Pl']),
#  'Plaza': set(['SouthPark Plaza', 'Wewatta Plaza', 'Wynkoop Plaza']),
#  'Point': set(['Buchanan Point',
#                'High Lonesome Point',
#                'Lodgewood Point',
#                'Lone Eagle Point',
#                'Pawnee Point',
#                'Red Feather Point',
#                'Sawtooth Point',
#                'Sleeping Owl Point']),
#  'R-250': set(['17th Street R-250']),
#  'Ramp': set(['Park Avenue West Ramp']),
#  'Raod': set(['South Parker Raod']),
#  'Rd': set(['Coalton Rd',
#             'Depot Hill Rd',
#             'E Arapahoe Rd',
#             'E Arapaphoe Rd',
#             'E Araphahoe Rd',
#             'E Araphoe Rd',
#             'E County Line Rd',
#             'E. Baseline Rd',
#             'E. Rim Rd',
#             'East Arapahoe Rd',
#             'Elk Creek Rd',
#             'Lagae Rd',
#             'Lookout Mountain Rd',
#             'Mt. Vernon Rd',
#             'Pine Valley Rd',
#             'S Golden Rd',
#             'S Mt Vernon Country Club Rd',
#             'S Parker Rd',
#             'S. Golden Rd',
#             'S. River Rd',
#             'South Parker Rd',
#             'West Ridge Rd']),
#  'Rd.': set(['402 Marshall Rd.',
#              'E. Happy Canyon Rd.',
#              'E. Rim Rd.',
#              'S. Jordan Rd.']),
#  'Row': set(['Colony Row']),
#  'Run': set(['Raven Run', 'Stage Run']),
#  'STreet': set(['Main STreet']),
#  'South': set(['57th Court South',
#                'Buchtel Boulevard South',
#                'East Cherry Creek Drive South',
#                'Inverness Drive South',
#                'Inverness Way South',
#                'Nautilus Court South',
#                'West 6th Avenue Frontage Road South']),
#  'Speer': set(['Speer']),
#  'St': set(['12th St',
#             '14th St',
#             '9th St',
#             'Broadway St',
#             'Commons St',
#             'Dahlia St',
#             'Dayton St',
#             'Dorchester St',
#             'Downing St',
#             'E Simpson St',
#             'East Evans St',
#             'First St',
#             'Glencoe St',
#             'Gold Hill St',
#             'Grant St',
#             'Grove St',
#             'Jefferson St',
#             'Larimer St',
#             'Main St',
#             'N Richfield St',
#             'N Salida St',
#             'N Washington St',
#             'Oak St',
#             'S Abilene St',
#             'S Akron St',
#             'S Broadway St',
#             'S Clayton St',
#             'S Columbine St',
#             'S Dallas St',
#             'S Delaware St',
#             'S Elizabeth St',
#             'S Franklin St',
#             'S Gaylord St',
#             'S Josephine St',
#             'S Logan St',
#             'S Newport St',
#             'S Niagra St',
#             'S Pearl St',
#             'S Peoria St',
#             'S Pontiac St',
#             'S Poplar St',
#             'S Quebec St',
#             'S Sherman St',
#             'S York St',
#             'South Grant St',
#             'South Havana St',
#             'South Sunset St',
#             'W Mulberry St',
#             'Washington St',
#             'Wewatta St',
#             'Wright St',
#             'Wynkoop St',
#             'Yukon St']),
#  'St.': set(['11265 Decatur St.',
#              'California St.',
#              'E Simpson St.',
#              'Little Raven St.',
#              'Main St.',
#              'Pearl St.',
#              'Purcell St.',
#              'Robert St.',
#              'S. Bannock St.',
#              'Tennyson St.']),
#  'Strret': set(['South Holly Strret']),
#  'Tennyson': set(['Tennyson']),
#  'Terrace': set(['SouthPark Terrace']),
#  'Thornton,': set(['4710 Washington St, Thornton,']),
#  'Ute': set(['West Ute']),
#  'Varra': set(['Via Varra']),
#  'WB': set(['E Orchard Rd Bike Lane WB']),
#  'Wadsworth': set(['Wadsworth']),
#  'Walnut': set(['Walnut']),
#  'West': set(['Castlegate Drive West',
#               'Indian Peaks Trail West',
#               'Inverness Drive West',
#               'Park Avenue West',
#               'South Carr Avenue West',
#               'Sterling Circle West']),
#  'Wewatta': set(['Wewatta']),
#  'Woodfern': set(['Woodfern']),
#  'ave.': set(['Pennsylvania ave.']),
#  'circle': set(['Oxford circle']),
#  'ct': set(['5270 w 100th ct', 'S Newcombe ct']),
#  'dr': set(['20 amaranth dr', 'W friend dr']),
#  'drive': set(['City View drive']),
#  'lane': set(['Lindenwood lane']),
#  'rd': set(['E. Arapahoe rd']),
#  'road': set(['south hover road']),
#  'st': set(['28th st', 'South Carr st']),
#  'trail': set(['shoshone trail'])}
# East Colfax => East Colfax
# Baseline => Baseline
# South Parker Rd => South Parker Road
# Elk Creek Rd => Elk Creek Road
# S Mt Vernon Country Club Rd => S Mt Vernon Country Club Road
# E. Rim Rd => E. Rim Road
# Lagae Rd => Lagae Road
# E Arapahoe Rd => E Arapahoe Road
# East Arapahoe Rd => East Arapahoe Road
# S. River Rd => S. River Road
# Mt. Vernon Rd => Mt. Vernon Road
# E County Line Rd => E County Line Road
# E. Baseline Rd => E. Baseline Road
# E Araphahoe Rd => E Araphahoe Road
# Lookout Mountain Rd => Lookout Mountain Road
# S Parker Rd => S Parker Road
# E Arapaphoe Rd => E Arapaphoe Road
# West Ridge Rd => West Ridge Road
# S. Golden Rd => S. Golden Road
# Depot Hill Rd => Depot Hill Road
# Coalton Rd => Coalton Road
# Pine Valley Rd => Pine Valley Road
# S Golden Rd => S Golden Road
# E Araphoe Rd => E Araphoe Road
# Newland => Newland
# Main STreet => Main STreet
# 4710 Washington St, Thornton, => 4710 Washington St, Thornton,
# Sheridan Boulevard Unit 5B => Sheridan Boulevard Unit 5B
# Sheridan Boulevard 5B => Sheridan Boulevard 5B
# E 88th => E 88th
# 17th Street R-250 => 17th Street R-250
# 6001 => 6001
# South Holly Strret => South Holly Strret
# Wadsworth Boulevard Ste 400 => Wadsworth Boulevard Ste 400
# 49th St #8 => 49th St #8
# CO HWY 8 => CO HWY 8
# Oxford circle => Oxford circle
# US Highway 285 => US Highway 285
# US Hwy 285 => US Hwy 285
# Highway 285 => Highway 285
# South Highway 287 => South Highway 287
# US Highway 287 => US Highway 287
# Highway 287 => Highway 287
# CO-119 => CO-119
# West Colfax Avenue, Unit D => West Colfax Avenue, Unit D
# E 3rd Ave #D => E 3rd Ave #D
# S Aurora Pkwy => S Aurora Parkway
# Castle Pines Pkwy => Castle Pines Parkway
# E Alameda Pkwy => E Alameda Parkway
# W Alameda Pkwy => W Alameda Parkway
# S Platte River Pkwy => S Platte River Parkway
# Orchard Pkwy => Orchard Parkway
# S Kipling Pkwy => S Kipling Parkway
# Wadsworth Pkwy => Wadsworth Parkway
# Evergreen Pkwy => Evergreen Parkway
# S Monaco Pkwy => S Monaco Parkway
# West 120th Avenue, Ste 120 => West 120th Avenue, Ste 120
# E Flatiron Cir => E Flatiron Circle
# S Lake Cir => S Lake Circle
# Rock Creek Cir => Rock Creek Circle
# Highlands Cir => Highlands Circle
# Via Appia => Via Appia
# County Rd 126 => County Rd 126
# 20 amaranth dr => 20 amaranth dr
# W friend dr => W friend dr
# Weld County Road 59 => Weld County Road 59
# Eagle River Loop => Eagle River Loop
# Quay Loop => Quay Loop
# I-76 & CO Hwy 52 => I-76 & CO Hwy 52
# State Highway 52 => State Highway 52
# E Caley Ave #130 => E Caley Ave #130
# West Magnolia Campground => West Magnolia Campground
# North Broadway => North Broadway
# S. Broadway => S. Broadway
# S Broadway => S Broadway
# N Broadway => N Broadway
# Broadway => Broadway
# South Broadway => South Broadway
# Grant => Grant
# Park Avenue West => Park Avenue West
# Sterling Circle West => Sterling Circle West
# South Carr Avenue West => South Carr Avenue West
# Indian Peaks Trail West => Indian Peaks Trail West
# Inverness Drive West => Inverness Drive West
# Castlegate Drive West => Castlegate Drive West
# Broadway, Ste 700 => Broadway, Ste 700
# Via Varra => Via Varra
# County Road 314 => County Road 314
# East Iliff Avenue #115 => East Iliff Avenue #115
# W Cross Dr #110 => W Cross Dr #110
# E. Mineral Avenue, Suite 110 => E. Mineral Avenue, Suite 110
# Wadsworth Bypass => Wadsworth Bypass
# North State Highway 83 => North State Highway 83
# State Highway 83 => State Highway 83
# Colorado Highway 83 => Colorado Highway 83
# 402 Marshall Rd. => 402 Marshall Road
# E. Happy Canyon Rd. => E. Happy Canyon Road
# S. Jordan Rd. => S. Jordan Road
# E. Rim Rd. => E. Rim Road
# Highway 119 => Highway 119
# State Highway 119 => State Highway 119
# E Lake Pl => E Lake Place
# E Orchard Pl => E Orchard Place
# E Maplewood Pl => E Maplewood Place
# W 88th Pl => W 88th Place
# W Lehigh Pl => W Lehigh Place
# Pinon Pl => Pinon Place
# W 16th Pl => W 16th Place
# US 85 => US 85
# Lamar => Lamar
# Stage Run => Stage Run
# Raven Run => Raven Run
# East Arapahoe Road, #140 => East Arapahoe Road, #140
# 2148 S. High Street, Denver, Colorado, 80208 => 2148 S. High Street, Denver, Colorado, 80208
# E. Arapahoe rd => E. Arapahoe rd
# West State Highway 7 => West State Highway 7
# SH 7 => SH 7
# County Road 7 => County Road 7
# State Highway 7 => State Highway 7
# University Blvd, Suite E1 => University Blvd, Suite E1
# East 19th Avenue  #6300 => East 19th Avenue  #6300
# East Bromley Lane (152nd Avenue) => East Bromley Lane (152nd Avenue)
# Folsom Street, #303 => Folsom Street, #303
# E. College Ave. => E. College Avenue
# 11200 W. 64th Ave. => 11200 W. 64th Avenue
# E. Mountain View Ave. => E. Mountain View Avenue
# W. Alameda Ave. => W. Alameda Avenue
# Santa Fe Drive, Unit #850 => Santa Fe Drive, Unit #850
# Wadsworth Boulevard, Ste 300 => Wadsworth Boulevard, Ste 300
# Crown Crest Blvd., Suite 300 => Crown Crest Blvd., Suite 300
# Commerce Center Cir #300 => Commerce Center Cir #300
# Delaware St #300 => Delaware St #300
# Norwood Drive Unit K => Norwood Drive Unit K
# Wynkoop Plaza => Wynkoop Plaza
# Wewatta Plaza => Wewatta Plaza
# SouthPark Plaza => SouthPark Plaza
# Tennyson => Tennyson
# 3101 E 100th Thornton, CO80229 => 3101 E 100th Thornton, CO80229
# Lawrence Street Mall => Lawrence Street Mall
# Pearl Street Mall => Pearl Street Mall
# 10th Street Mall => 10th Street Mall
# Central Campus Mall => Central Campus Mall
# 15th Street #103 => 15th Street #103
# South Ridgeline Blvd, Suite 100 => South Ridgeline Blvd, Suite 100
# Sheridan Boulevard #100 => Sheridan Boulevard #100
# 15th Street Suite 100 => 15th Street Suite 100
# Landmark Way, Suite 106 => Landmark Way, Suite 106
# Dorchester St #107 => Dorchester St #107
# Cherry Creek S Dr #104 => Cherry Creek S Dr #104
# Sheridan Blvd. => Sheridan Blvd.
# Co-119 => Co-119
# Woodfern => Woodfern
# Sawtooth Point => Sawtooth Point
# Lone Eagle Point => Lone Eagle Point
# Pawnee Point => Pawnee Point
# Sleeping Owl Point => Sleeping Owl Point
# Buchanan Point => Buchanan Point
# Lodgewood Point => Lodgewood Point
# Red Feather Point => Red Feather Point
# High Lonesome Point => High Lonesome Point
# DTC Pky => DTC Parkway
# Centennial => Centennial
# Rodeo Ct => Rodeo Court
# S Niagra Ct => S Niagra Court
# North 57th Ct => North 57th Court
# Pear Lake Ct => Pear Lake Court
# South 57th Ct => South 57th Court
# E Orchard Rd Bike Lane WB => E Orchard Rd Bike Lane WB
# south hover road => south hover road
# Colony Row => Colony Row
# Wadsworth => Wadsworth
# Caria => Caria
# S Alton Way #9k => S Alton Way #9k
# 128th Ave MUP => 128th Ave MUP
# East Elm => East Elm
# West Magnolia Camground => West Magnolia Camground
# 11265 Decatur St. => 11265 Decatur Street
# Purcell St. => Purcell Street
# Pearl St. => Pearl Street
# California St. => California Street
# S. Bannock St. => S. Bannock Street
# Main St. => Main Street
# Little Raven St. => Little Raven Street
# Tennyson St. => Tennyson Street
# E Simpson St. => E Simpson Street
# Robert St. => Robert Street
# Wewatta => Wewatta
# County Road 65 => County Road 65
# US 36 Bikeway => US 36 Bikeway
# 5270 w 100th ct => 5270 w 100th Court
# S Newcombe ct => S Newcombe Court
# Boulder => Boulder
# Central Court North => Central Court North
# Parkside Drive North => Parkside Drive North
# Nautilus Court North => Nautilus Court North
# 57th Court North => 57th Court North
# East Speer Boulevard North => East Speer Boulevard North
# Colorado SR 2 => Colorado SR 2
# State Highway 2 => State Highway 2
# Colorado SH 2 => Colorado SH 2
# Delaware St Unit 2 => Delaware St Unit 2
# SR 2 => SR 2
# County Road 186 => County Road 186
# Nautilus Court South => Nautilus Court South
# Buchtel Boulevard South => Buchtel Boulevard South
# East Cherry Creek Drive South => East Cherry Creek Drive South
# Inverness Way South => Inverness Way South
# West 6th Avenue Frontage Road South => West 6th Avenue Frontage Road South
# 57th Court South => 57th Court South
# Inverness Drive South => Inverness Drive South
# 1606 => 1606
# Etna => Etna
# Weaver Park Rd #500 => Weaver Park Rd #500
# Lincoln => Lincoln
# Colorado Blvd #B => Colorado Blvd #B
# 4th Street Suite B => 4th Street Suite B
# Garden Center => Garden Center
# West Ute => West Ute
# Pennsylvania => Pennsylvania
# Yellow Locust => Yellow Locust
# N Salida St => N Salida Street
# W Mulberry St => W Mulberry Street
# Dorchester St => Dorchester Street
# S Quebec St => S Quebec Street
# S Peoria St => S Peoria Street
# Downing St => Downing Street
# South Grant St => South Grant Street
# S Franklin St => S Franklin Street
# Wright St => Wright Street
# Washington St => Washington Street
# Yukon St => Yukon Street
# S Broadway St => S Broadway Street
# South Havana St => South Havana Street
# Main St => Main Street
# S Sherman St => S Sherman Street
# S Abilene St => S Abilene Street
# S Niagra St => S Niagra Street
# S Clayton St => S Clayton Street
# Larimer St => Larimer Street
# Oak St => Oak Street
# S Gaylord St => S Gaylord Street
# E Simpson St => E Simpson Street
# S Pontiac St => S Pontiac Street
# Dayton St => Dayton Street
# First St => First Street
# S Dallas St => S Dallas Street
# Gold Hill St => Gold Hill Street
# 12th St => 12th Street
# N Richfield St => N Richfield Street
# Commons St => Commons Street
# Glencoe St => Glencoe Street
# S Akron St => S Akron Street
# S Poplar St => S Poplar Street
# East Evans St => East Evans Street
# Wewatta St => Wewatta Street
# S Newport St => S Newport Street
# S Delaware St => S Delaware Street
# South Sunset St => South Sunset Street
# Grant St => Grant Street
# Broadway St => Broadway Street
# N Washington St => N Washington Street
# 14th St => 14th Street
# S York St => S York Street
# S Pearl St => S Pearl Street
# S Logan St => S Logan Street
# S Elizabeth St => S Elizabeth Street
# Grove St => Grove Street
# Dahlia St => Dahlia Street
# Jefferson St => Jefferson Street
# 9th St => 9th Street
# S Josephine St => S Josephine Street
# S Columbine St => S Columbine Street
# Wynkoop St => Wynkoop Street
# shoshone trail => shoshone trail
# 6523 => 6523
# S Broadway #169 => S Broadway #169
# 30th St #220H => 30th St #220H
# Hwy 72 & Hwy 93 => Hwy 72 & Hwy 93
# Walnut => Walnut
# South Colorado Boulevard, #220 => South Colorado Boulevard, #220
# Osage => Osage
# Pennsylvania ave. => Pennsylvania ave.
# 12354 West Alameda Parkway Lakewood Colorado => 12354 West Alameda Parkway Lakewood Colorado
# South Rock Creek Parkway, Building 19 => South Rock Creek Parkway, Building 19
# W Quincy Ave => W Quincy Avenue
# Evans Ave => Evans Avenue
# E Arizona Ave => E Arizona Avenue
# w 67th Ave => w 67th Avenue
# w. 10th Ave => w. 10th Avenue
# W Hampden Ave => W Hampden Avenue
# Arapahoe Ave => Arapahoe Avenue
# W Floyd Ave => W Floyd Avenue
# W 38th Ave => W 38th Avenue
# E Fair Ave => E Fair Avenue
# E 120th Ave => E 120th Avenue
# East Mississippi Ave => East Mississippi Avenue
# W 84th Ave => W 84th Avenue
# W 72nd Ave => W 72nd Avenue
# E 1st Ave => E 1st Avenue
# E Louisiana Ave => E Louisiana Avenue
# W. 10th Ave => W. 10th Avenue
# W 44th Ave => W 44th Avenue
# Dorado Ave => Dorado Avenue
# Cottonwood Ave => Cottonwood Avenue
# E 84th Ave => E 84th Avenue
# Dawn Ave => Dawn Avenue
# West 120th Ave => West 120th Avenue
# W 10th Ave => W 10th Avenue
# E 6th Ave => E 6th Avenue
# W Ken Caryl Ave => W Ken Caryl Avenue
# East Hampden Ave => East Hampden Avenue
# W Plymouth Ave => W Plymouth Avenue
# Washington Ave => Washington Avenue
# W. 25th Ave => W. 25th Avenue
# Yarmouth Ave => Yarmouth Avenue
# E Caley Ave => E Caley Avenue
# E Maplewood Ave => E Maplewood Avenue
# W 64th Ave => W 64th Avenue
# E 72nd Ave => E 72nd Avenue
# West 136th Ave => West 136th Avenue
# W 120th Ave => W 120th Avenue
# E Evans Ave => E Evans Avenue
# Baselin => Baselin
# West 136th Avenue Unit 154 => West 136th Avenue Unit 154
# Tuscany Ln => Tuscany Ln
# Lee Ln => Lee Ln
# Coal Mine => Coal Mine
# Main => Main
# South Valley Highway => South Valley Highway
# Diagonal Highway => Diagonal Highway
# Ute Highway => Ute Highway
# North Valley Highway => North Valley Highway
# West 25th Avenue Suit 200c => West 25th Avenue Suit 200c
# Village Center Drive East => Village Center Drive East
# Inverness Drive East => Inverness Drive East
# Sterling Circle East => Sterling Circle East
# South Chapparal Circle East => South Chapparal Circle East
# Inverness Court East => Inverness Court East
# State Highway 86 => State Highway 86
# County Road 45 => County Road 45
# US Hwy 40 => US Hwy 40
# US Highway 40 => US Highway 40
# County Road 41 => County Road 41
# E Arapahoe Rd Tower 1 #320 => E Arapahoe Rd Tower 1 #320
# S Valley Hwy => S Valley Hwy
# Arapahoe => Arapahoe
# Indian Peaks Dr => Indian Peaks Drive
# Community Circle Dr => Community Circle Drive
# Apache Dr => Apache Drive
# Conifer Town Denter Dr => Conifer Town Denter Drive
# Community Center Dr => Community Center Drive
# Reliance Dr => Reliance Drive
# Zotos Dr => Zotos Drive
# Broadlands Dr => Broadlands Drive
# Cabela Dr => Cabela Drive
# Eisenhower Dr => Eisenhower Drive
# Lakeview Dr => Lakeview Drive
# Leetsdale Dr => Leetsdale Drive
# Cowley Dr => Cowley Drive
# Longs Peak Dr => Longs Peak Drive
# Melody Dr => Melody Drive
# Delwood Dr => Delwood Drive
# S Santa Fe Dr => S Santa Fe Drive
# SouthPark Terrace => SouthPark Terrace
# South Road A => South Road A
# Wadsworth Boulevard, Ste. 200 => Wadsworth Boulevard, Ste. 200
# S Bellaire St #200 => S Bellaire St #200
# 68th => 68th
# 1100 Ken Pratt Blvd Unit E => 1100 Ken Pratt Blvd Unit E
# Main Street #E => Main Street #E
# 4775 West 121st Ace => 4775 West 121st Ace
# 5005 West 120th Ace => 5005 West 120th Ace
# East Mainstreet => East Mainstreet
# Park Avenue West Ramp => Park Avenue West Ramp
# Colorado 74 => Colorado 74
# County Road 74 => County Road 74
# Highway 74 => Highway 74
# Hwy 74 => Hwy 74
# County Road 73 => County Road 73
# Hwy 73 => Hwy 73
# CO Highway 73 => CO Highway 73
# Park 72 => Park 72
# CO 72 => CO 72
# County Road 72 => County Road 72
# Cherryvale => Cherryvale
# South Parker Raod => South Parker Raod
# Lindenwood lane => Lindenwood lane
# P.O. Box 7331 => P.O. Box 7331
# Speer => Speer
# City View drive => City View drive
# 28th st => 28th st
# South Carr st => South Carr st
# 8765 => 8765
# 1190 South Lashley Lane Boulder, CO 80305 => 1190 South Lashley Lane Boulder, CO 80305
# Front View Crescent => Front View Crescent
# Interlocken Crescent => Interlocken Crescent
# W 56th Av => W 56th Av
# W Belleview Av => W Belleview Av
# Wadworth Blvd => Wadworth Blvd
# S Lowell Blvd => S Lowell Blvd
# Green Valley Ranch Blvd => Green Valley Ranch Blvd
# Eldorado Blvd => Eldorado Blvd
# Wadsworth Blvd => Wadsworth Blvd
# Federal Blvd => Federal Blvd
# S University Blvd => S University Blvd
# Martin Luther King Blvd => Martin Luther King Blvd
# Sheridan Blvd => Sheridan Blvd
# Brighton Blvd => Brighton Blvd
# N Federal Blvd => N Federal Blvd
# McCaslin Blvd => McCaslin Blvd
# Martin Luther King Jr Blvd => Martin Luther King Jr Blvd
# Airport Blvd => Airport Blvd
# N Sheridan Blvd => N Sheridan Blvd
# S University  Blvd => S University  Blvd
# 745 Colorado Blvd => 745 Colorado Blvd
# South Colorado Blvd => South Colorado Blvd
# Colorado Blvd => Colorado Blvd
# East Academy Blvd => East Academy Blvd
# Ken Pratt Blvd => Ken Pratt Blvd
# South University Blvd => South University Blvd

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        # YOUR CODE HERE
        for tag in element.iter("tag"):
            #print tag.attrib['k']
            if re.search(lower, tag.attrib['k']):
                keys["lower"]+= 1
            elif re.search(lower_colon, tag.attrib['k']):
                keys["lower_colon"]+=1
            elif re.search(problemchars, tag.attrib['k']):
                keys["problemchars"]+= 1
            else:
                keys["other"]+=1
            
        pass
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
def test():
    keys = process_map(OSMFILE)
    pprint.pprint(keys)
    
test()
# Out:
# {'lower': 1277544, 'lower_colon': 786521, 'other': 43010, 'problemchars': 4}

# %%
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if element.get("uid"):
            users.add(element.attrib["uid"])
    return users


def test():
    users = process_map(OSMFILE)
    pprint.pprint(users)
    
test()
# Out:
# set(['1',
#      '1007528',
#      '101433',
#      '104962',
#      '104996',
#      '1051550',
#      '1058308',
#      '1061145',
#      '1066803',
#      '10727',
#      '1073158',
#      '10786',
#      '1081635',
#      '1087647',
#      '1089728',
#      '1090081',
#      '109724',
#      '110263',
#      '110541',
#      '1110270',
#      '11154',
#      '111791',
#      '112856',
#      '113624',
#      '114161',
#      '1149057',
#      '115468',
#      '1168918',
#      '117055',
#      '1190873',
#      '1195030',
#      '1195257',
#      '1195295',
#      '119785',
#      '1209932',
#      '121241',
#      '1222367',
#      '1229318',
#      '123364',
#      '1233879',
#      '1234087',
#      '1237910',
#      '1239795',
#      '1240849',
#      '1240894',
#      '12434',
#      '125718',
#      '1260280',
#      '1263353',
#      '128470',
#      '129127',
#      '129531',
#      '129614',
#      '12982',
#      '1306',
#      '131059',
#      '131218',
#      '131996',
#      '13203',
#      '13257',
#      '132807',
#      '1339694',
#      '135163',
#      '135329',
#      '1355974',
#      '13591',
#      '13817',
#      '13832',
#      '139555',
#      '139856',
#      '14233',
#      '1427179',
#      '14293',
#      '1442206',
#      '1443767',
#      '145231',
#      '1468382',
#      '147510',
#      '1494110',
#      '150272',
#      '152074',
#      '152294',
#      '1535212',
#      '153669',
#      '1538681',
#      '153919',
#      '1539368',
#      '15398',
#      '154164',
#      '154991',
#      '155628',
#      '155796',
#      '1559983',
#      '158230',
#      '158340',
#      '15902',
#      '160949',
#      '1611',
#      '161206',
#      '161951',
#      '1624486',
#      '162529',
#      '165',
#      '1651798',
#      '165869',
#      '16591',
#      '16703',
#      '1679',
#      '1679807',
#      '169004',
#      '1694420',
#      '1703428',
#      '1704768',
#      '1706611',
#      '17068',
#      '1710022',
#      '1714450',
#      '1718724',
#      '172061',
#      '1721969',
#      '1722904',
#      '1723161',
#      '1729842',
#      '1731253',
#      '1741998',
#      '1745406',
#      '1746371',
#      '17467',
#      '1747690',
#      '1770239',
#      '1778953',
#      '1779165',
#      '1783785',
#      '178415',
#      '1785948',
#      '178626',
#      '1797574',
#      '1799878',
#      '1802220',
#      '1807548',
#      '181135',
#      '1814808',
#      '1818960',
#      '1820939',
#      '1829683',
#      '1836535',
#      '1837671',
#      '1845758',
#      '1848908',
#      '1849272',
#      '1850404',
#      '1858262',
#      '1866129',
#      '1878743',
#      '1883744',
#      '1883838',
#      '1884848',
#      '188805',
#      '1890807',
#      '189572',
#      '191112',
#      '1912347',
#      '1917282',
#      '1941575',
#      '1941999',
#      '1944192',
#      '1944235',
#      '1945697',
#      '1945842',
#      '1945906',
#      '1945916',
#      '1945934',
#      '1951346',
#      '1952288',
#      '1952353',
#      '1953169',
#      '1953198',
#      '1953602',
#      '1954049',
#      '1954201',
#      '1954246',
#      '1954253',
#      '1954284',
#      '1954311',
#      '1954373',
#      '1963099',
#      '1963249',
#      '1964337',
#      '1965779',
#      '1968068',
#      '1968655',
#      '1972184',
#      '1972608',
#      '1987840',
#      '1996335',
#      '2010518',
#      '2012449',
#      '2017512',
#      '2052948',
#      '2053369',
#      '20587',
#      '2065516',
#      '207581',
#      '207745',
#      '2077897',
#      '207864',
#      '20846',
#      '208674',
#      '2098497',
#      '2103318',
#      '210584',
#      '2115749',
#      '2125929',
#      '21323',
#      '2137840',
#      '214103',
#      '2144635',
#      '2163532',
#      '2164',
#      '217618',
#      '2181182',
#      '21931',
#      '2209894',
#      '2217601',
#      '2219338',
#      '22195',
#      '2226712',
#      '223093',
#      '2237750',
#      '2252312',
#      '227972',
#      '2281193',
#      '2281503',
#      '2288692',
#      '232126',
#      '2323380',
#      '2323512',
#      '232785',
#      '232968',
#      '234600',
#      '2347504',
#      '2358753',
#      '2361839',
#      '2362607',
#      '236585',
#      '2377377',
#      '238196',
#      '238584',
#      '239998',
#      '2406207',
#      '2429366',
#      '2444712',
#      '246',
#      '2462028',
#      '2462227',
#      '2475974',
#      '2481824',
#      '2504518',
#      '2505100',
#      '2508151',
#      '2511706',
#      '2512300',
#      '252751',
#      '25418',
#      '2547321',
#      '2554698',
#      '25729',
#      '25867',
#      '262151',
#      '26299',
#      '2644101',
#      '2655992',
#      '266857',
#      '2671319',
#      '2679756',
#      '2740984',
#      '2748195',
#      '2753132',
#      '27541',
#      '2756402',
#      '2778924',
#      '2779208',
#      '2786924',
#      '2800396',
#      '2800498',
#      '28145',
#      '2819232',
#      '2820190',
#      '2823295',
#      '283157',
#      '2835928',
#      '28378',
#      '2847988',
#      '2859402',
#      '28775',
#      '2881088',
#      '28852',
#      '28887',
#      '2890576',
#      '2890854',
#      '28923',
#      '289297',
#      '2900624',
#      '2905914',
#      '292665',
#      '292893',
#      '293012',
#      '2941385',
#      '297131',
#      '2999979',
#      '3000556',
#      '301588',
#      '3049136',
#      '30521',
#      '30554',
#      '305985',
#      '3060926',
#      '3069035',
#      '3085665',
#      '310589',
#      '312902',
#      '313067',
#      '313192',
#      '313700',
#      '3151684',
#      '3160484',
#      '31855',
#      '3206645',
#      '3207726',
#      '325053',
#      '3254650',
#      '325554',
#      '3257366',
#      '3260493',
#      '3272286',
#      '32952',
#      '331621',
#      '3331544',
#      '3343450',
#      '334389',
#      '334722',
#      '336211',
#      '336460',
#      '33703',
#      '338293',
#      '3386951',
#      '3387325',
#      '33916',
#      '3397583',
#      '339917',
#      '3427283',
#      '3441377',
#      '3445434',
#      '3464017',
#      '346480',
#      '3478684',
#      '3481954',
#      '3521724',
#      '3526564',
#      '3546434',
#      '355161',
#      '355242',
#      '3560',
#      '3582',
#      '358440',
#      '359133',
#      '3594360',
#      '360392',
#      '36121',
#      '3618405',
#      '362431',
#      '3645783',
#      '365944',
#      '366306',
#      '3684350',
#      '36894',
#      '369357',
#      '3693603',
#      '3696213',
#      '369709',
#      '370127',
#      '371121',
#      '3716570',
#      '37392',
#      '374193',
#      '377053',
#      '379381',
#      '3807176',
#      '381253',
#      '381909',
#      '382071',
#      '38446',
#      '38487',
#      '385027',
#      '385127',
#      '3861393',
#      '3877019',
#      '388278',
#      '389565',
#      '38998',
#      '390033',
#      '390611',
#      '3913914',
#      '3918941',
#      '3924027',
#      '392708',
#      '3962',
#      '39688',
#      '39726',
#      '3973280',
#      '3987945',
#      '4018392',
#      '402624',
#      '402714',
#      '40397',
#      '4042060',
#      '4054',
#      '4071710',
#      '4073',
#      '407827',
#      '408202',
#      '4094991',
#      '4115',
#      '41231',
#      '412649',
#      '414016',
#      '414318',
#      '4151894',
#      '415250',
#      '41928',
#      '4210803',
#      '42191',
#      '4224085',
#      '4224321',
#      '42429',
#      '426005',
#      '42619',
#      '426815',
#      '4277075',
#      '43021',
#      '437598',
#      '43972',
#      '4406342',
#      '443130',
#      '443255',
#      '445221',
#      '445671',
#      '4459720',
#      '446855',
#      '4469663',
#      '4470972',
#      '4475490',
#      '4475678',
#      '447903',
#      '450189',
#      '451693',
#      '4542289',
#      '45480',
#      '455725',
#      '45952',
#      '4606673',
#      '46088',
#      '461005',
#      '463651',
#      '464006',
#      '464644',
#      '464770',
#      '4660',
#      '466374',
#      '4697',
#      '4720805',
#      '4732',
#      '474179',
#      '475877',
#      '4764681',
#      '478074',
#      '478161',
#      '47892',
#      '4801391',
#      '481116',
#      '48176',
#      '4834480',
#      '484323',
#      '4858543',
#      '4868421',
#      '487141',
#      '4891661',
#      '49031',
#      '4927013',
#      '494591',
#      '495102',
#      '497227',
#      '4983364',
#      '5009468',
#      '5012631',
#      '5025331',
#      '503983',
#      '5043588',
#      '506866',
#      '507436',
#      '508',
#      '51045',
#      '510836',
#      '51136',
#      '51324',
#      '513431',
#      '514123',
#      '5175682',
#      '5183446',
#      '5183526',
#      '5185232',
#      '5186778',
#      '5199411',
#      '5200853',
#      '5201312',
#      '5201406',
#      '5209271',
#      '5210094',
#      '5215858',
#      '522807',
#      '5228960',
#      '5251455',
#      '52797',
#      '530223',
#      '53127',
#      '533465',
#      '5359',
#      '548288',
#      '548684',
#      '553260',
#      '553971',
#      '55661',
#      '55916',
#      '5611',
#      '567792',
#      '570272',
#      '571489',
#      '576968',
#      '580469',
#      '58440',
#      '586964',
#      '593205',
#      '596695',
#      '5974',
#      '597941',
#      '598489',
#      '602100',
#      '60244',
#      '604586',
#      '60650',
#      '609753',
#      '612325',
#      '6157',
#      '618879',
#      '620273',
#      '620817',
#      '62218',
#      '626974',
#      '643278',
#      '644706',
#      '646613',
#      '649112',
#      '650990',
#      '652301',
#      '653607',
#      '660445',
#      '662440',
#      '664567',
#      '665694',
#      '666728',
#      '66904',
#      '680979',
#      '682',
#      '684885',
#      '689604',
#      '68982',
#      '693405',
#      '696731',
#      '70',
#      '702735',
#      '703517',
#      '70359',
#      '70453',
#      '70696',
#      '709340',
#      '709543',
#      '711265',
#      '711717',
#      '7168',
#      '74228',
#      '748175',
#      '751666',
#      '751766',
#      '7591',
#      '76002',
#      '76352',
#      '76547',
#      '771165',
#      '772720',
#      '790345',
#      '79882',
#      '80285',
#      '81024',
#      '81197',
#      '81285',
#      '82317',
#      '82513',
#      '84054',
#      '84681',
#      '850941',
#      '8703',
#      '87938',
#      '88164',
#      '883016',
#      '88337',
#      '88961',
#      '8909',
#      '896824',
#      '91156',
#      '91266',
#      '91499',
#      '92286',
#      '92937',
#      '93334',
#      '93679',
#      '93788',
#      '94230',
#      '94578',
#      '95488',
#      '98002',
#      '988026',
#      '98876',
#      '99282',
#      '994480',
#      '99476',
#      '99615'])

# %%
# %load 'schema.py'
schema.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-2c4cfc858c10> in <module>()
#       1 # %load 'schema.py'
# ----> 2 schema.py
#
# AttributeError: 'module' object has no attribute 'py'

# %%
import csv
import codecs
import cerberus
import schema

OSM_PATH = OSMFILE

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    if element.tag == 'node':
        node_attribs = {}    
        tags = []
        
        for item in NODE_FIELDS:
            if item == 'lat':
                node_attribs[item] = element.attrib[item].strip()
            else:
                node_attribs[item] = element.attrib[item]

        for tag in element.iter("tag"):  
 
            match_prob = PROBLEMCHARS.search(tag.attrib['k'])
            
            if not match_prob:
                node_tag_dict = {} 
                node_tag_dict['id'] = element.attrib['id'] 
                node_tag_dict['value'] = tag.attrib['v']  

                m = LOWER_COLON.search(tag.attrib['k'])
                if not m:
                    node_tag_dict['type'] = 'regular'
                    node_tag_dict['key'] = tag.attrib['k']
                else:
                    chars_before_colon = re.findall('^(.+?):', tag.attrib['k'])
                    chars_after_colon = re.findall('^[a-z_]+:(.+)', tag.attrib['k'])
                    
                    node_tag_dict['type'] = chars_before_colon[0]
                    node_tag_dict['key'] = chars_after_colon[0]

            tags.append(node_tag_dict)
        
        return {'node': node_attribs, 'node_tags': tags}
    
    elif element.tag == 'way':
        way_attribs = {}
        way_nodes = []
        tags = []  
    
        for item in WAY_FIELDS:
            way_attribs[item] = element.attrib[item]
    
        for tag in element.iter("tag"):  
 
            match_prob = PROBLEMCHARS.search(tag.attrib['k'])
            if not match_prob:
                way_tag_dict = {}
                way_tag_dict['id'] = element.attrib['id'] 
                way_tag_dict['value'] = tag.attrib['v']  

                m = LOWER_COLON.search(tag.attrib['k'])
                if not m:
                    way_tag_dict['type'] = 'regular'
                    way_tag_dict['key'] = tag.attrib['k']
                else:
                    chars_before_colon = re.findall('^(.+?):', tag.attrib['k'])
                    chars_after_colon = re.findall('^[a-z_]+:(.+)', tag.attrib['k'])

                    way_tag_dict['type'] = chars_before_colon[0]
                    way_tag_dict['key'] = chars_after_colon[0]

            tags.append(way_tag_dict)
        
        
        count = 0
        for tag in element.iter("nd"):  
            way_nd_dict = {} 
            way_nd_dict['id'] = element.attrib['id'] 
            way_nd_dict['node_id'] = tag.attrib['ref'] 
            way_nd_dict['position'] = count  
            count += 1
            
            way_nodes.append(way_nd_dict)
    
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

# %%
process_map(OSM_PATH, validate=False)

# %%
import sqlite3

db = sqlite3.connect("den2")
c = db.cursor()
c2 = db.cursor()
QUERY = """SELECT n.lat, n.lon from nodes as n"""
q2 = """select nt.value, count(*) from nodes_tags as nt
        group by nt.value
        order by count(*) desc"""
c.execute(QUERY)
c2.execute(q2)
rows = c.fetchall()
rows2 = c2.fetchall()

db.close()

# %%
hp = 39.75
vp = -105.010845

q1 = 0
q2 = 0
q3 = 0
q4 = 0

print len(rows)
for row in rows:
    try:
        lat = float(row[0].strip())
    except:
        continue
    try:
        lon = float(row[1])
    except:
        continue
    if lat > hp:
        if lon < vp:
            q1 += 1
        else:
            q2 += 1
    elif lat < hp:
        if lon < vp:
            q4 += 1
        else:
            q3 += 1
        
print q1, q2, q3, q4
# Out:
# 8757993
# 3074419 1234075 2526140 1399067

# %%
db = sqlite3.connect("den2")
c = db.cursor()
c2 = db.cursor()
QUERY = """select count(nt.key) from nodes_tags as nt
            where nt.key = 'brewery';"""
q2 = """select nt.value from nodes_tags as nt
            where nt.key = 'postcode'
        limit 10;"""
c.execute(QUERY)
c2.execute(q2)
rows = c.fetchall()
rows2 = c2.fetchall()

print rows

db.close()
# Out:
# [(85,)]

# %%
db = sqlite3.connect("den2")
c = db.cursor()
c2 = db.cursor()
QUERY = """select nt.key, count(distinct nt.key) from nodes_tags as nt
            group by nt.key order by count(nt.key) desc limit 100;"""

q2 = """select n.user, count(distinct n.id) from nodes_tags as nt
        join nodes as n on n.id = nt.id
        where nt.key = 'brewery'
        group by n.user
        order by count(n.id) desc;"""
c.execute(QUERY)
c2.execute(q2)
rows = c.fetchall()
rows2 = c2.fetchall()


db.close()

# %%
from pprint import pprint
pprint (rows2)
# Out:
# [(u'ColoMapper', 70),
#  (u'chachafish', 10),
#  (u'Your Village Maps', 2),
#  (u'Spanholz', 1),
#  (u'mattchn', 1)]
